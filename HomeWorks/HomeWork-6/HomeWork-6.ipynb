# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import MeanSquaredError

# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]  # e.g., age 20–100, BMI 15–55, HR 60–160

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='tanh'),  # hidden layer with tanh activation
    Dense(1, activation='linear')                    # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # perfect prediction line
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %% [markdown]
# # part A

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]  # e.g., age 20–100, BMI 15–55, HR 60–160

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with 4 neurons in hidden layer ---
model = Sequential([
    Dense(4, input_shape=(3,), activation='tanh'),  # hidden layer با ۴ نورون
    Dense(1, activation='linear')                    # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (4 Neurons in Hidden Layer)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (4 Neurons)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]  # e.g., age 20–100, BMI 15–55, HR 60–160

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with 64 neurons in hidden layer ---
model = Sequential([
    Dense(64, input_shape=(3,), activation='tanh'),  # hidden layer با ۶۴ نورون
    Dense(1, activation='linear')                     # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (64 Neurons in Hidden Layer)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (64 Neurons)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...

# %% [markdown]
# # part B

# %% [markdown]
# ReLU

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]  # e.g., age 20–100, BMI 15–55, HR 60–160

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with ReLU activation ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='relu'),  # hidden layer با ReLU
    Dense(1, activation='linear')                    # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (Activation = ReLU)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (ReLU)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %% [markdown]
# Sigmoid

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with Sigmoid activation ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='sigmoid'),  # hidden layer با سیگموید
    Dense(1, activation='linear')                       # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (Activation = Sigmoid)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (Sigmoid)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %% [markdown]
# ELU (Exponential Linear Unit)

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with ELU activation ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='elu'),  # hidden layer با ELU
    Dense(1, activation='linear')                   # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (Activation = ELU)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (ELU)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %% [markdown]
#  SELU (Scaled Exponential Linear Unit)

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with SELU activation ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='selu', kernel_initializer='lecun_normal'),  # hidden layer با SELU
    Dense(1, activation='linear')                                                     # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (Activation = SELU)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (SELU)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %% [markdown]
# Softplus

# %%
# --- Generate synthetic dataset ---
np.random.seed(0)
n_samples = 300

# Input features: age, BMI, heart rate
X = np.random.rand(n_samples, 3) * [80, 40, 100] + [20, 15, 60]

# Target: blood pressure with some noise
y = 0.4 * X[:, 0] + 1.2 * X[:, 1] + 0.2 * X[:, 2] + np.random.randn(n_samples) * 5

# --- Preprocessing: standardize inputs ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# --- Build shallow neural network with Softplus activation ---
model = Sequential([
    Dense(10, input_shape=(3,), activation='softplus'),  # hidden layer با Softplus
    Dense(1, activation='linear')                        # output layer for regression
])

# Compile model
model.compile(optimizer=SGD(learning_rate=0.01), loss=MeanSquaredError())

# --- Train model and save history ---
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=0)

# --- Visualize training and validation loss ---
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs (Activation = Softplus)')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# --- Predict and visualize results ---
y_pred = model.predict(X_test)

plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('True Blood Pressure')
plt.ylabel('Predicted Blood Pressure')
plt.title('True vs Predicted Values (Softplus)')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
